# %%
#Include packages and builtin classes
import pandas as pd
import sklearn
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report, confusion_matrix

# %%
# Load Seeds dataset (whitespace separated)
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/00236/seeds_dataset.txt"
names = ['area','perimeter','compactness','length_of_kernel','width_of_kernel',
         'asymmetry_coefficient','length_of_kernel_groove','Class']
seedsdata = pd.read_csv(url, delim_whitespace=True, names=names)
# Out:
# /tmp/ipython-input-1133897101.py:5: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   seedsdata = pd.read_csv(url, delim_whitespace=True, names=names)

# %%
X = seedsdata.iloc[:, 0:7]
y = seedsdata.iloc[:, 7:8]

# %%
X.head()
# Out:
#     area  perimeter  compactness  length_of_kernel  width_of_kernel  \
# 0  15.26      14.84       0.8710             5.763            3.312
# 1  14.88      14.57       0.8811             5.554            3.333
# 2  14.29      14.09       0.9050             5.291            3.337
# 3  13.84      13.94       0.8955             5.324            3.379
# 4  16.14      14.99       0.9034             5.658            3.562
#
#    asymmetry_coefficient  length_of_kernel_groove
# 0                  2.221                    5.220
# 1                  1.018                    4.956
# 2                  2.699                    4.825
# 3                  2.259                    4.805
# 4                  1.355                    5.175

# %%
y.head()
# Out:
#    Class
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0

# %%
y.Class.unique()
# Out:
# array([0, 1, 2])

# %%
le = preprocessing.LabelEncoder()
y = y.apply(le.fit_transform)
y.head()
# Out:
#    Class
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20)

# %%
scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
mlp = MLPClassifier(hidden_layer_sizes=(10, 10, 10), max_iter=1000)
mlp.fit(X_train, y_train.values.ravel())
# Out:
# MLPClassifier(hidden_layer_sizes=(10, 10, 10), max_iter=1000)

# %%
predictions = mlp.predict(X_test)
print(predictions)
# Out:
# [1 0 1 1 2 0 2 1 0 0 0 2 2 2 1 1 2 2 0 1 2 1 1 0 0 0 0 0 1 0 1 1 0 2 0 0 0
#  2 2 2 2 2]

# %%
print(confusion_matrix(y_test,predictions))
# Out:
# [[12  3  1]
#  [ 1  9  0]
#  [ 3  0 13]]

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.75      0.75        16
#            1       0.75      0.90      0.82        10
#            2       0.93      0.81      0.87        16
#
#     accuracy                           0.81        42
#    macro avg       0.81      0.82      0.81        42
# weighted avg       0.82      0.81      0.81        42
